# %% [markdown]
# # High School Statistics Applications on Iris Sepals and Petals dataset

# %% [markdown]
# ***
# ## Iris Dataset

# %% [markdown]
# dataset source : https://www.kaggle.com/datasets/uciml/iris

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import random

# import python files
from hs_stats import z_score

# %%
data = pd.read_csv('datasets/iris.csv')
display(data)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# lists
SL = data["SepalLengthCm"]
SW = data["SepalWidthCm"]
PL = data["PetalLengthCm"]
PW = data["PetalWidthCm"]
Spec = data["Species"]

# %% [markdown]
# ***
# ## Demonstration of Z-Score and Standard Deviation relationship using Sepal Lengths data

# %% [markdown]
# $datapoint = \bar{x} + (z \times \sigma)$

# %%
print(f'min : {min(SL)}  max : {max(SL)}\n')

SLmean = round(float(SL.mean()),3)
SLvar = round(float(SL.var(0)),3)
SLstd = round(float(SL.std(0)),3)

print(f'mean : {SLmean}')
print(f'variance : {SLvar}')
print(f'standard deviation : {SLstd}')
# Out:
# min : 4.3  max : 7.9
#
# mean : 5.843
# variance : 0.686
# standard deviation : 0.828

# %%
# random sepal lengths
rand_SL = [4.341, 6.35, 7.067]

# %%
for x in rand_SL :
    print(f'SEPAL LENGTH {x}')
    z = round(z_score(SL,x),3)
    print(f' - z-score : {z}')
    print(f' - {SLmean} + ({z} * {SLstd}) = {round(SLmean + (z * SLstd),3)}\n')
# Out:
# SEPAL LENGTH 4.341
#  - z-score : -1.814
#  - 5.843 + (-1.814 * 0.828) = 4.341
#
# SEPAL LENGTH 6.35
#  - z-score : 0.612
#  - 5.843 + (0.612 * 0.828) = 6.35
#
# SEPAL LENGTH 7.067
#  - z-score : 1.478
#  - 5.843 + (1.478 * 0.828) = 7.067

# %% [markdown]
# ***
# ## Data Visualisation

# %% [markdown]
# ### Boxplot

# %%
plt.boxplot([SL, SW, PL, PW], tick_labels = ["Sepal Lengths", "Sepal Widths", "Petal Lengths", "Petal Widths"])
plt.title("Sepal and Petal Lengths and Widths")
plt.ylabel("cm")
plt.show()

# %%
from collections import Counter
# Out:
# 35

# %% [markdown]
# ### Histograms

# %%
# Sepal Lengths & Widths
plt.hist(SL, alpha = 0.5, label = "sepal lengths", color = "red")
plt.hist(SW, alpha = 0.5, label = "sepal widths", color = "blue")
plt.title("Sepal Lengths and Widths")
plt.xlabel("cm")
plt.ylabel("number of individuals")
plt.legend()
plt.show()

# %%
# Petal Lengths & Widths
plt.hist(PL, alpha = 0.5, label = "petal lengths", color = "red")
plt.hist(PW, alpha = 0.5, label = "petal widths", color = "blue")
plt.title("Petal Lengths and Widths")
plt.xlabel("cm")
plt.ylabel("number of individuals")
plt.legend()
plt.show()

# %%
# Sepal & Petal Lengths
plt.hist(SL, alpha = 0.5, label = "sepal lengths", color = "red")
plt.hist(PL, alpha = 0.5, label = "petal lengths", color = "blue")
plt.title("Sepal and Petal Lengths")
plt.xlabel("cm")
plt.ylabel("number of individuals")
plt.legend()
plt.show()

# %%
# Sepal & Petal Widths
plt.hist(SW, alpha = 0.5, label = "sepal widths", color = "red")
plt.hist(PW, alpha = 0.5, label = "petal widths", color = "blue")
plt.title("Sepal and Petal Widths")
plt.xlabel("cm")
plt.ylabel("number of individuals")
plt.legend()
plt.show()

# %% [markdown]
# ### Scatter plots

# %%
# Sepal Lengths & Widths
plt.scatter(SL,SW)
plt.title("Sepal Lengths and Widths (cm)")
plt.xlabel("Sepal Lengths")
plt.ylabel("Sepal Widths")
plt.show()

# %%
# Petal Lengths & Widths
plt.scatter(PL,PW)
plt.title("Petal Lengths and Widths (cm)")
plt.xlabel("Petal Lengths")
plt.ylabel("Petal Widths")
plt.show()

# %%
# Sepal & Petal Lengths
plt.scatter(SL,PL)
plt.title("Sepal and Petal Lengths (cm)")
plt.xlabel("Sepal Lengths")
plt.ylabel("Petal Lengths")
plt.show()

# %%
# Sepal & Petal Widths
plt.scatter(SW,PW)
plt.title("Sepal and Petal Widths (cm)")
plt.xlabel("Sepal Widths")
plt.ylabel("Petal Widths")
plt.show()
